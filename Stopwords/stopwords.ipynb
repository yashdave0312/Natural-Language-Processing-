# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
corpus = """Natural Language Processing is a field of artificial intelligence that helps computers understand human language. It is used in many applications such as chatbots, search engines, translation systems, and recommendation systems.

The goal of NLP is to process text so that computers can understand it and extract useful information from it. A computer does not naturally understand language in the same way that humans do, so different techniques are used to transform text into a form that a machine can work with.

One of the first steps in NLP is text preprocessing. It includes several tasks such as tokenization, removing stopwords, stemming, lemmatization, and converting text into numerical representations.

Stopwords are common words that usually do not carry much useful information for a particular NLP task. Words such as the, is, are, was, were, a, an, and, or, but, in, on, at, to, from, for, with, by, of, this, that, it, and as are often considered stopwords.

When we remove stopwords from a sentence, the sentence becomes shorter and focuses more on the important words. For example, the sentence "The student is learning NLP from the online course" can be reduced to "student learning NLP online course" after removing common stopwords.

However, stopwords should not always be removed. Sometimes these words are important for understanding the meaning of a sentence. For example, in a question such as "Who is not going to school?", removing the word "not" could completely change the meaning.

NLP is used in many areas of our daily lives. It can help people search for information on the internet, communicate with virtual assistants, translate languages, analyze customer reviews, detect spam messages, and summarize large amounts of text.

The data used for NLP can come from books, websites, social media, emails, news articles, conversations, and many other sources. Before a machine learning model can use this data, the text usually needs to be cleaned and processed.

Python provides several useful libraries for NLP. NLTK is one of the popular libraries used for learning NLP concepts. It provides tools for tokenization, stemming, lemmatization, stopword removal, and many other natural language processing tasks.

Learning how stopwords work is important because it helps us understand the process of converting raw text into useful information. After learning stopwords, we can explore other NLP concepts such as stemming, lemmatization, word embeddings, TF-IDF, and text classification."""
