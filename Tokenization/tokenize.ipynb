# %%
corpus = """Tokenization is one of the fundamental preprocessing steps in Natural Language Processing (NLP). It is the process of breaking a piece of text into smaller units called tokens. These tokens can be individual words, sentences, or even characters, depending on the type of tokenization being performed. For example, the sentence "Natural Language Processing is interesting." can be divided into word tokens such as ["Natural", "Language", "Processing", "is", "interesting"]. Tokenization helps an NLP system understand and process human language by converting unstructured text into smaller, manageable units. It is commonly used as a first step before tasks such as text classification, sentiment analysis, machine translation, text generation, and information extraction."""

# %%
corpus
# Out:
# 'Tokenization is one of the fundamental preprocessing steps in Natural Language Processing (NLP). It is the process of breaking a piece of text into smaller units called tokens. These tokens can be individual words, sentences, or even characters, depending on the type of tokenization being performed. For example, the sentence "Natural Language Processing is interesting." can be divided into word tokens such as ["Natural", "Language", "Processing", "is", "interesting"]. Tokenization helps an NLP system understand and process human language by converting unstructured text into smaller, manageable units. It is commonly used as a first step before tasks such as text classification, sentiment analysis, machine translation, text generation, and information extraction.'

# %%
# paragraph --> sentence
from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)
documents
# Out:
# ['Tokenization is one of the fundamental preprocessing steps in Natural Language Processing (NLP).',
#  'It is the process of breaking a piece of text into smaller units called tokens.',
#  'These tokens can be individual words, sentences, or even characters, depending on the type of tokenization being performed.',
#  'For example, the sentence "Natural Language Processing is interesting."',
#  'can be divided into word tokens such as ["Natural", "Language", "Processing", "is", "interesting"].',
#  'Tokenization helps an NLP system understand and process human language by converting unstructured text into smaller, manageable units.',
#  'It is commonly used as a first step before tasks such as text classification, sentiment analysis, machine translation, text generation, and information extraction.']

# %%
# Paragraphs into words , sentence into words 
from nltk.tokenize import word_tokenize,wordpunct_tokenize
words = word_tokenize(corpus)
print(words)
words1 = wordpunct_tokenize(corpus)
print(words1)
# Out:
# ['Tokenization', 'is', 'one', 'of', 'the', 'fundamental', 'preprocessing', 'steps', 'in', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', '.', 'It', 'is', 'the', 'process', 'of', 'breaking', 'a', 'piece', 'of', 'text', 'into', 'smaller', 'units', 'called', 'tokens', '.', 'These', 'tokens', 'can', 'be', 'individual', 'words', ',', 'sentences', ',', 'or', 'even', 'characters', ',', 'depending', 'on', 'the', 'type', 'of', 'tokenization', 'being', 'performed', '.', 'For', 'example', ',', 'the', 'sentence', '``', 'Natural', 'Language', 'Processing', 'is', 'interesting', '.', "''", 'can', 'be', 'divided', 'into', 'word', 'tokens', 'such', 'as', '[', '``', 'Natural', "''", ',', '``', 'Language', "''", ',', '``', 'Processing', "''", ',', '``', 'is', "''", ',', '``', 'interesting', "''", ']', '.', 'Tokenization', 'helps', 'an', 'NLP', 'system', 'understand', 'and', 'process', 'human', 'language', 'by', 'converting', 'unstructured', 'text', 'into', 'smaller', ',', 'manageable', 'units', 
# ...

# %%
# sentence --> words
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Tokenization', 'is', 'one', 'of', 'the', 'fundamental', 'preprocessing', 'steps', 'in', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', '.']
# ['It', 'is', 'the', 'process', 'of', 'breaking', 'a', 'piece', 'of', 'text', 'into', 'smaller', 'units', 'called', 'tokens', '.']
# ['These', 'tokens', 'can', 'be', 'individual', 'words', ',', 'sentences', ',', 'or', 'even', 'characters', ',', 'depending', 'on', 'the', 'type', 'of', 'tokenization', 'being', 'performed', '.']
# ['For', 'example', ',', 'the', 'sentence', '``', 'Natural', 'Language', 'Processing', 'is', 'interesting', '.', "''"]
# ['can', 'be', 'divided', 'into', 'word', 'tokens', 'such', 'as', '[', '``', 'Natural', "''", ',', '``', 'Language', "''", ',', '``', 'Processing', "''", ',', '``', 'is', "''", ',', '``', 'interesting', "''", ']', '.']
# ...

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Tokenization',
#  'is',
#  'one',
#  'of',
#  'the',
#  'fundamental',
#  'preprocessing',
#  'steps',
#  'in',
#  'Natural',
#  'Language',
#  'Processing',
#  '(',
#  'NLP',
#  ')',
#  '.',
#  'It',
#  'is',
#  'the',
#  'process',
#  'of',
#  'breaking',
#  'a',
#  'piece',
#  'of',
#  'text',
#  'into',
#  'smaller',
#  'units',
#  'called',
#  'tokens.',
#  'These',
#  'tokens',
#  'can',
#  'be',
#  'individual',
#  'words',
#  ',',
#  'sentences',
#  ',',
#  'or',
#  'even',
#  'characters',
#  ',',
#  'depending',
#  'on',
#  'the',
#  'type',
#  'of',
#  'tokenization',
#  'being',
#  'performed.',
#  'For',
#  'example',
#  ',',
#  'the',
#  'sentence',
#  '``',
#  'Natural',
#  'Language',
#  'Processing',
#  'is',
#  'interesting.',
#  "''",
#  'can',
#  'be',
#  'divided',
#  'into',
#  'word',
#  'tokens',
#  'such',
#  'as',
#  '[',
#  '``',
#  'Natural',
#  "''",
#  ',',
#  '``',
#  'Language',
#  "''",
#  ',',
#  '``',
#  'Processing',
#  "''",
#  ',',
#  '``',
# ...
